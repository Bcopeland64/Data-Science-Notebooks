# %% [markdown]
# <a href="https://colab.research.google.com/github/Bcopeland64/Data-Science-Notebooks/blob/master/LazyPredict_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 10.1MB 19.0MB/s
# ...
#      |████████████████████████████████| 25.9MB 41.4MB/s
# ...
#      |████████████████████████████████| 307kB 44.9MB/s
# ...
#      |████████████████████████████████| 81kB 9.1MB/s
# ...
#      |████████████████████████████████| 276kB 46.4MB/s
# ...
#      |████████████████████████████████| 6.8MB 37.0MB/s
# ...
#      |████████████████████████████████| 1.2MB 43.3MB/s
# ...
#      |████████████████████████████████| 14.5MB 336kB/s
# ...
#      |████████████████████████████████| 127.6MB 93kB/s
# ...
#      |████████████████████████████████| 256kB 54.1MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=62e70327edd66b8f46358be53e644e33ce658061327dbf54c3a9fe4357e029f3
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built PyYAML
# ERROR: tensorflow 2.4.1 has requirement numpy~=1.19.2, but you'll have numpy 1.19.1 which is incompatible.
# ...

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data = load_breast_cancer()
X = data.data
y = data.target

X__train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
clf = LazyClassifier(verbose=1, ignore_warnings=True, custom_metric=None)
train, test = clf.fit(X__train, X_test, y_train, y_test)
# Out:
#  14%|█▍        | 4/29 [00:00<00:01, 15.14it/s]
# {'Model': 'AdaBoostClassifier', 'Accuracy': 0.9766081871345029, 'Balanced Accuracy': 0.9748677248677249, 'ROC AUC': 0.9748677248677248, 'F1 Score': 0.9766081871345029, 'Time taken': 0.16639018058776855}
# {'Model': 'BaggingClassifier', 'Accuracy': 0.9473684210526315, 'Balanced Accuracy': 0.9451058201058201, 'ROC AUC': 0.9451058201058201, 'F1 Score': 0.9474532329725615, 'Time taken': 0.06619024276733398}
# {'Model': 'BernoulliNB', 'Accuracy': 0.9649122807017544, 'Balanced Accuracy': 0.9623015873015872, 'ROC AUC': 0.9623015873015873, 'F1 Score': 0.9649122807017544, 'Time taken': 0.013859748840332031}
# {'Model': 'CalibratedClassifierCV', 'Accuracy': 0.9766081871345029, 'Balanced Accuracy': 0.9715608465608465, 'ROC AUC': 0.9715608465608465, 'F1 Score': 0.9765268453762402, 'Time taken': 0.044287681579589844}
# ...

# %%
train
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LogisticRegression                 0.98  ...        0.06
# Perceptron                         0.98  ...        0.02
# XGBClassifier                      0.98  ...        0.20
# LinearSVC                          0.98  ...        0.06
# SVC                                0.98  ...        0.05
# PassiveAggressiveClassifier        0.98  ...        0.02
# AdaBoostClassifier                 0.98  ...        0.17
# ExtraTreesClassifier               0.98  ...        0.16
# CalibratedClassifierCV             0.98  ...        0.04
# SGDClassifier                      0.96  ...        0.03
# RandomForestClassifier             0.97  ...        0.23
# QuadraticDiscriminantAnalysis      0.96  ...        0.03
# BernoulliNB                        0.96  ...        0.01
# KNeighborsClassifier               0.96  ...        0.02
# LGBMClassifier                     0.95  ...        0.13
# ...

# %%
test
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LogisticRegression                 0.98  ...        0.06
# Perceptron                         0.98  ...        0.02
# XGBClassifier                      0.98  ...        0.20
# LinearSVC                          0.98  ...        0.06
# SVC                                0.98  ...        0.05
# PassiveAggressiveClassifier        0.98  ...        0.02
# AdaBoostClassifier                 0.98  ...        0.17
# ExtraTreesClassifier               0.98  ...        0.16
# CalibratedClassifierCV             0.98  ...        0.04
# SGDClassifier                      0.96  ...        0.03
# RandomForestClassifier             0.97  ...        0.23
# QuadraticDiscriminantAnalysis      0.96  ...        0.03
# BernoulliNB                        0.96  ...        0.01
# KNeighborsClassifier               0.96  ...        0.02
# LGBMClassifier                     0.95  ...        0.13
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(x='Accuracy', y=train.index, data=train)
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  <a list of 7 Text major ticklabel objects>)

# %%
#Regression Version
import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import numpy as np

data = datasets.load_boston()
X = data.data
y = data.target

X__train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
Rgsr = LazyRegressor(verbose=1, ignore_warnings=True, custom_metric=None)
train, test = Rgsr.fit(X__train, X_test, y_train, y_test)
# Out:
#  12%|█▏        | 5/42 [00:00<00:01, 22.94it/s]
# {'Model': 'AdaBoostRegressor', 'R-Squared': 0.7931261186579607, 'Adjusted R-Squared': 0.7736379994011019, 'RMSE': 3.926170308447529, 'Time taken': 0.13388371467590332}
# {'Model': 'BaggingRegressor', 'R-Squared': 0.863021570043229, 'Adjusted R-Squared': 0.8501178049023738, 'RMSE': 3.194790578755556, 'Time taken': 0.061374664306640625}
# {'Model': 'BayesianRidge', 'R-Squared': 0.7085867181684281, 'Adjusted R-Squared': 0.6811347423437148, 'RMSE': 4.659839666647522, 'Time taken': 0.014578104019165039}
# {'Model': 'DecisionTreeRegressor', 'R-Squared': 0.8442008232392547, 'Adjusted R-Squared': 0.8295240891965758, 'RMSE': 3.4072098478620925, 'Time taken': 0.018251419067382812}
# {'Model': 'DummyRegressor', 'R-Squared': -0.03469753992352409, 'Adjusted R-Squared': -0.13216904730762424, 'RMSE': 8.780576101609647, 'Time taken': 0.010976076126098633}
# ...

# %%
train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.88       0.89  2.85        0.17
# ExtraTreesRegressor                          0.87       0.88  3.00        0.21
# XGBRegressor                                 0.86       0.87  3.09        0.08
# RandomForestRegressor                        0.86       0.87  3.10        0.36
# BaggingRegressor                             0.85       0.86  3.19        0.06
# HistGradientBoostingRegressor                0.84       0.85  3.30        0.26
# DecisionTreeRegressor                        0.83       0.84  3.41        0.02
# LGBMRegressor                                0.83       0.84  3.42        0.07
# AdaBoostRegressor                            0.77       0.79  3.93        0.13
# PoissonRegressor                             0.76       0.78  4.01        0.02
# KNeighborsRegressor                          0.72       0.75  4.34        0.02
# ...

# %%
test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.88       0.89  2.85        0.17
# ExtraTreesRegressor                          0.87       0.88  3.00        0.21
# XGBRegressor                                 0.86       0.87  3.09        0.08
# RandomForestRegressor                        0.86       0.87  3.10        0.36
# BaggingRegressor                             0.85       0.86  3.19        0.06
# HistGradientBoostingRegressor                0.84       0.85  3.30        0.26
# DecisionTreeRegressor                        0.83       0.84  3.41        0.02
# LGBMRegressor                                0.83       0.84  3.42        0.07
# AdaBoostRegressor                            0.77       0.79  3.93        0.13
# PoissonRegressor                             0.76       0.78  4.01        0.02
# KNeighborsRegressor                          0.72       0.75  4.34        0.02
# ...

# %%
train['R-Squared'] = [0 if i < 0 else i for i in train.iloc[:,0]]

plt.figure(figsize=(20,10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(x='R-Squared', y=train.index, data=train)
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 6 Text major ticklabel objects>)
