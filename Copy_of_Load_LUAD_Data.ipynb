# %% [markdown]
# <a href="https://colab.research.google.com/github/Bcopeland64/Data-Science-Notebooks/blob/master/Copy_of_Load_LUAD_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O Filtered_Renamed_LUAD.csv.gz https://github.com/Phibio2LUAD/LUAD_DATA/raw/main/Filtered_Renamed_LUAD.csv.gz
# Out:
# --2021-01-22 12:52:00--  https://github.com/Phibio2LUAD/LUAD_DATA/raw/main/Filtered_Renamed_LUAD.csv.gz
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Phibio2LUAD/LUAD_DATA/main/Filtered_Renamed_LUAD.csv.gz [following]
# --2021-01-22 12:52:00--  https://raw.githubusercontent.com/Phibio2LUAD/LUAD_DATA/main/Filtered_Renamed_LUAD.csv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23482134 (22M) [application/octet-stream]
# Saving to: ‘Filtered_Renamed_LUAD.csv.gz’
#
# Filtered_Renamed_LU 100%[===================>]  22.39M   107MB/s    in 0.2s
#
# ...

# %%
import gzip
import shutil
import pandas as pd

# %%
with gzip.open('Filtered_Renamed_LUAD.csv.gz', 'rb') as fin, open('Filtered_Renamed_LUAD.csv', 'wb') as fout:
    shutil.copyfileobj(fin, fout)

# %%
Data = pd.read_csv('Filtered_Renamed_LUAD.csv', index_col='GeneID')

# %%
Data
# Out:
#                  TCGA-J2-8192-01A  ...  TCGA-05-4420-01A
# GeneID                             ...
# ENSG00000146083         10.661934  ...          8.771928
# ENSG00000198242         81.616770  ...        186.597075
# ENSG00000134108         28.928312  ...         29.278537
# ENSG00000167700          7.009133  ...         14.025164
# ENSG00000070087         11.528930  ...         54.640415
# ...                           ...  ...               ...
# ENSG00000099991         10.069992  ...         11.671122
# ENSG00000102265        251.539296  ...        261.432238
# ENSG00000133313         11.162795  ...         12.179765
# ENSG00000066044          9.888901  ...         16.292292
# ENSG00000105063         12.615595  ...         10.289900
#
# [5571 rows x 594 columns]

# %%
import numpy as np

# %%
Data = np.log2(Data+1)

# %%
Data
# Out:
#                  TCGA-J2-8192-01A  ...  TCGA-05-4420-01A
# GeneID                             ...
# ENSG00000146083          3.543735  ...          3.288643
# ENSG00000198242          6.368363  ...          7.551494
# ENSG00000134108          4.903439  ...          4.920224
# ENSG00000167700          3.001646  ...          3.909309
# ENSG00000070087          3.647191  ...          5.798061
# ...                           ...  ...               ...
# ENSG00000099991          3.468582  ...          3.663472
# ENSG00000102265          7.980364  ...          8.035801
# ENSG00000133313          3.604403  ...          3.720253
# ENSG00000066044          3.444786  ...          4.112057
# ENSG00000105063          3.767188  ...          3.496961
#
# [5571 rows x 594 columns]

# %%
(Data >= 10).sum(axis=1) > len(Data.columns)/4
# Out:
# GeneID
# ENSG00000146083    False
# ENSG00000198242    False
# ENSG00000134108    False
# ENSG00000167700    False
# ENSG00000070087    False
#                    ...
# ENSG00000099991    False
# ENSG00000102265    False
# ENSG00000133313    False
# ENSG00000066044    False
# ENSG00000105063    False
# Length: 5571, dtype: bool

# %%
Data[(Data >= 10).sum(axis=1) > len(Data.columns)/4]
# Out:
#                  TCGA-J2-8192-01A  ...  TCGA-05-4420-01A
# GeneID                             ...
# ENSG00000198888         10.288962  ...         11.763759
# ENSG00000197956         10.569549  ...          9.903393
# ENSG00000198786          9.654482  ...          8.390525
# ENSG00000198899         11.355615  ...         11.772568
# ENSG00000185303          6.614648  ...          2.311658
# ENSG00000198938         12.421416  ...         12.349627
# ENSG00000019582         11.030404  ...          7.667337
# ENSG00000198727         10.918018  ...         11.622597
# ENSG00000234745          9.758969  ...          7.548732
# ENSG00000196126         10.084477  ...          5.693851
# ENSG00000112306          8.773253  ...          9.885775
# ENSG00000087086         11.881130  ...         11.500392
# ENSG00000184009          9.369474  ...          9.989897
# ENSG00000212907         10.372880  ...         10.848400
# ENSG00000205542         10.255783  ...         11.345361
# ...

# %%
from scipy.stats import zscore

# %%
Data[Data.columns] = zscore(Data, axis=1)

# %%
Data
# Out:
#                  TCGA-J2-8192-01A  ...  TCGA-05-4420-01A
# GeneID                             ...
# ENSG00000146083         -0.203432  ...         -0.673840
# ENSG00000198242         -1.223020  ...          0.750090
# ENSG00000134108         -0.003892  ...          0.037734
# ENSG00000167700         -0.370606  ...          0.650097
# ENSG00000070087         -0.474929  ...          1.148123
# ...                           ...  ...               ...
# ENSG00000099991          0.235461  ...          0.577653
# ENSG00000102265          0.045754  ...          0.099196
# ENSG00000133313         -1.248299  ...         -1.018659
# ENSG00000066044         -0.280510  ...          1.889673
# ENSG00000105063         -0.349834  ...         -0.841733
#
# [5571 rows x 594 columns]

# %%
Data.describe()
# Out:
#        TCGA-J2-8192-01A  TCGA-75-5122-01A  ...  TCGA-S2-AA1A-01A  TCGA-05-4420-01A
# count       5571.000000       5571.000000  ...       5571.000000       5571.000000
# mean           0.039011         -0.032284  ...          0.015743          0.140888
# std            0.736353          0.985528  ...          0.860474          1.144990
# min           -2.585292         -6.053898  ...         -3.052340         -3.525686
# 25%           -0.500889         -0.656578  ...         -0.590439         -0.688557
# 50%            0.002267         -0.072895  ...         -0.044043          0.132060
# 75%            0.517288          0.524113  ...          0.560462          0.919282
# max            3.150050          5.232385  ...          4.429912          4.876309
#
# [8 rows x 594 columns]

# %%
Transposed_Df = Data.T.copy()

# %%
Transposed_Df[Transposed_Df.columns] = zscore(Transposed_Df, axis=1)

# %%
Transposed_Df.describe()
# Out:
# GeneID  ENSG00000146083  ENSG00000198242  ...  ENSG00000066044  ENSG00000105063
# count        594.000000       594.000000  ...       594.000000       594.000000
# mean           0.063775        -0.023589  ...        -0.007692         0.061857
# std            0.955188         0.961498  ...         0.906995         0.903789
# min           -2.438949        -2.616640  ...        -3.402561        -2.181171
# 25%           -0.557976        -0.758643  ...        -0.643257        -0.511256
# 50%            0.064279        -0.035807  ...         0.026038         0.003802
# 75%            0.650170         0.656202  ...         0.614513         0.596318
# max            3.422238         2.593476  ...         2.404972         3.970354
#
# [8 rows x 5571 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

gene_list=[] 

with open('/content/drive/My Drive/uniprot.tab', newline = '\n') as file:
    read_files = csv.reader(file, delimiter='\t')
    for file in read_files:
        temporary = file[0]
        temporary_split_genes = temporary.split(',') 
        gene_length = len(temporary_split_genes)
        if gene_length > 1:
            for i in range(0, gene_length):
                gene_list.append(gene_list[i])
        else:
             gene_list.append(file[0])

# %%
len(gene_list)
# Out:
# 19354

# %%
print(len(np.unique(gene_list)))
# Out:
# 19146

# %%
from pandas import DataFrame
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %%
df = DataFrame (gene_list ,columns=['gene_id'])

# %%
final_gene_list = np.unique(gene_list)

# %%
print(final_gene_list)
# Out:
# ['ENSG00000000003' 'ENSG00000000005' 'ENSG00000000419' ...
#  'ENSG00000280969' 'ENSG00000281106'
#  'yourlist:M20210122A94466D2655679D1FD8953E075198DA833EA75B']

# %%
Data.iloc[:,:17].hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f17a4602f60>,
# ...
#       dtype=object)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
mms = MinMaxScaler()
mms.fit(Data)
data_transformed = mms.transform(Data)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('# of Clusters')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
mms = MinMaxScaler()
mms.fit(Transposed_Df)
data_transformed1 = mms.transform(Transposed_Df)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed1)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('# of clusters')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
New_Transposed_Df = Transposed_Df.rename(index = {'GeneID':'Patients'}, inplace=True)
